# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from scipy.stats import multivariate_normal as mvn
import matplotlib.pylab as plt

# %% [markdown]
# # Noise variants

# %%
def static_noise(N, mod=1, d=2):
    return mvn.rvs(cov=np.eye(d) * mod, size=N)

def hill_noise(N, low=1, mid=10, top=15):
    """  ____
        /
    ___/
    """
    lower = mvn.rvs(cov=np.eye(2)*low, size=20)
    middle = np.array([mvn.rvs(cov=np.eye(2)*i, size=1) for i in range(mid)])
    upper = mvn.rvs(cov=np.eye(2)*top, size=N-mid-20)
    return np.concatenate([lower, middle, upper])

def sin_noise(N, sin_halves=2):
    a = np.sin([np.pi * (sin_halves*i/N) for i in range(N)])
    return np.array([a,a]).T

# %%
n_hill = hill_noise(300)
plt.plot(n_hill)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbd88e001d0>,
#  <matplotlib.lines.Line2D at 0x7fbd88e00358>]

# %%
n_sin = static_noise(300) * sin_noise(300)
plt.plot(n_sin)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbd8904a2b0>,
#  <matplotlib.lines.Line2D at 0x7fbd8904a160>]

# %%
RMSE_START = 20

# %%
from kfsims.common import init_trajectory, init_all
from kfsims.node import node_factory

def daniels_variant(measurements, true, cov, rho=0.95, u=5):
    iterations = 10
    _, xk, P, tau, _, _, _, H, F, Q, N = init_all()
    U = cov * (u - 3)
    nd = node_factory(xk, P, u, U, F, Q, H, rho, tau, 
                      observe_factory(measurements.T), iterations)
    nd()
    preds = np.array(nd.logger['x']).squeeze()
    return preds, nd.post_rmse(true.T, start_element=RMSE_START), np.std(s, axis=0)

from filterpy.kalman import KalmanFilter
from filterpy.common import Q_discrete_white_noise
from kfsims.node import observe_factory

def classic_kf(traj, measurements, true, cov):
    my_filter = KalmanFilter(dim_x=4, dim_z=2)    
    my_filter.x = np.array([[0],[0],[1],[1]])
    my_filter.F = traj.A
    my_filter.H = traj.H
    my_filter.P = 100 * np.eye(4)
    
    my_filter.R = cov
    my_filter.Q = traj.Q
    
    rec = []
    for zk in observe_factory(measurements.T)():
        my_filter.predict()
        my_filter.update(zk)
        x = my_filter.x
        rec.append(x)

    preds = np.array(rec)[:, :, 0]
    s = np.sqrt((preds[RMSE_START:] - true[RMSE_START:]) ** 2)
    return preds, np.mean(s, axis=0), np.std(s, axis=0)

# %%
trj = init_trajectory()
true_traj = trj.X.T
cov_traj = trj.R

# %% [markdown]
# # Static noise
# ## Known exactly
# Expected: There should be no difference between CKF and VBKF. R should *not* change

# %%
N_t = 250

# %%
# basically np.eye(2)
np.random.seed(10)
n_static = static_noise(250, mod=4)
cov_init = np.cov(n_static.T) + cov_traj
msrms = trj.Y + n_static.T

# %%
res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init)
rms_dv
# Out:
# array([0.97042872, 0.8641359 , 1.05734817, 1.07517491])

# %%
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
rms_kfc
# Out:
# array([0.92206991, 0.8267738 , 1.06143106, 1.01681551])

# %%
res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [0.97042872 0.8641359  1.05734817 1.07517491]
# [0.92206991 0.8267738  1.06143106 1.01681551]

# %%
from utils import plot_single, plot_variants_only, plot_variants

# %%
f, ax = plt.subplots(1,1, figsize=(10, 5))
plot_single(ax, 0, res_dv, res_kfc, true_traj, msrms, 0)

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)

# %% [markdown]
# # Static noise - unknown
# Prostě prásknu covariance matrix jako np.eye(2). Bayes se dokáže adaptovat, CKF ne.

# %%
# basically np.eye(2)
np.random.seed(10)
n_static = static_noise(N_t, mod=1)
cov_init = np.eye(2)*0.1 #np.cov(n_static.T) + cov_traj
msrms = trj.Y + n_static.T

res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [0.88375271 0.80434755 1.05351919 1.07021077]
# [1.06738868 1.0786684  2.44251779 2.6054367 ]

# %%
plot_variants(res_dv, res_kfc, msrms, true_traj, 0)

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)

# %% [markdown]
# # Hill noise
# ## Known
# Nastavíme na průměrnou covarianci - tady opět pomáháme CKF, protože průměrnou cov většinou nemáme.

# %%
np.random.seed(10)
n_hill = hill_noise(N_t)
cov_init = np.cov(n_hill.T) + cov_traj
msrms = trj.Y + n_hill.T

res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init, rho=0.9)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [1.09537222 1.1470474  1.03533349 1.16231616]
# [1.09337816 1.03220831 1.07638697 1.07883179]

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)

# %% [markdown]
# # Unknown
# Bayes by se měl umět přizpůsobit, CKF ne

# %%
np.random.seed(10)
n_hill = hill_noise(250)
cov_init = np.eye(2) #np.cov(n_hill.T) #+ cov_traj
msrms = trj.Y + n_hill.T

res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init, rho=0.9)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [1.10257455 1.14896581 1.03409819 1.16613758]
# [1.48439865 1.33559602 1.83656356 1.90426823]

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)

# %% [markdown]
# # Sinus noise
# # Known

# %%
np.random.seed(10)
n_sin = static_noise(N_t) * sin_noise(N_t, 6) * 3
cov_init = np.cov(n_sin.T) + cov_traj
msrms = trj.Y + n_sin.T

res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init, rho=0.9)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [1.38008825 0.85051233 1.32316516 1.05474525]
# [1.32048364 0.84141613 1.34153541 1.02603039]

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)

# %% [markdown]
# # Unknown

# %%
np.random.seed(10)
#n_sin = static_noise(300) * sin_noise(300, 6) * 3
cov_init = np.eye(2)*0.1 #np.cov(n_sin.T) + cov_traj
msrms = trj.Y + n_sin.T

res_dv, rms_dv = daniels_variant(msrms, true_traj, cov_init, rho=0.9)
res_kfc, rms_kfc = classic_kf(trj, msrms, true_traj, cov_init)
print(rms_dv)
print(rms_kfc)
# Out:
# [1.41362244 0.90280718 1.35187357 1.07542244]
# [1.43552059 1.31311984 3.25395722 3.2558626 ]

# %%
plot_variants_only(res_dv, res_kfc, true_traj, 0)
